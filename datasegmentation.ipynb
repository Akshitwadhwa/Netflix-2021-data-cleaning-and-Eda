# %%
import numpy as np                 # for numerical computing
import pandas as pd                # for dataframe and manipulation
import seaborn as sns              #for graphs and data visualization
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
net_new = pd.read_csv("new_dataset.csv")
net_new.head(5)
# Out:
#   show_id     type                             title  \
# 0      s3  TV Show                         Ganglands
# 1      s6  TV Show                     Midnight Mass
# 2      s7    Movie  My Little Pony: A New Generation
# 3      s8    Movie                           Sankofa
# 4      s9  TV Show     The Great British Baking Show
#
#                         director  \
# 0                Julien Leclercq
# 1                  Mike Flanagan
# 2  Robert Cullen, José Luis Ucha
# 3                   Haile Gerima
# 4                Andy Devonshire
#
#                                                 cast  \
# 0  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 1  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 2  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 3  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 4  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# ...

# %%
net = net_new['listed_in'].str.split(",", n=2)
net  # Use `n` for maxsplit in pandas `.str.split()`
# Out:
# 0       [Crime TV Shows,  International TV Shows,  TV ...
# 1                  [TV Dramas,  TV Horror,  TV Mysteries]
# 2                              [Children & Family Movies]
# 3       [Dramas,  Independent Movies,  International M...
# 4                         [British TV Shows,  Reality TV]
#                               ...
# 5695          [Dramas,  International Movies,  Thrillers]
# 5696                   [Cult Movies,  Dramas,  Thrillers]
# 5697                           [Comedies,  Horror Movies]
# 5698                [Children & Family Movies,  Comedies]
# 5699    [Dramas,  International Movies,  Music & Music...
# Name: listed_in, Length: 5700, dtype: object

# %%
net_new['Genre 1'] = net.str.get(0)
net_new['Genre 2'] = net.str.get(1)
net_new['Genre 3'] = net.str.get(2)
# here we have defined the new generes wherer they will be put so that we have the data in different segment
net_new.head(5)
# Out:
#   show_id     type                             title  \
# 0      s3  TV Show                         Ganglands
# 1      s6  TV Show                     Midnight Mass
# 2      s7    Movie  My Little Pony: A New Generation
# 3      s8    Movie                           Sankofa
# 4      s9  TV Show     The Great British Baking Show
#
#                         director  \
# 0                Julien Leclercq
# 1                  Mike Flanagan
# 2  Robert Cullen, José Luis Ucha
# 3                   Haile Gerima
# 4                Andy Devonshire
#
#                                                 cast  \
# 0  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 1  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 2  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 3  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 4  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# ...

# %%
# we are going to describe each of the genres and the count in each one
net_new['Genre 1'].describe(include=all)
# here we see that
# Out:
# count       5700
# unique        33
# top       Dramas
# freq        1586
# Name: Genre 1, dtype: object
